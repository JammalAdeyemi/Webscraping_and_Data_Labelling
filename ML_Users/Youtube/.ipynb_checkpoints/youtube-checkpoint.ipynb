# %% [markdown]
# ## Using python and flask to scrape the data from someones youtube channel exposing their raw stats via a JSON API?

# %%
from googleapiclient.discovery import build
import json
import pandas as pd
import seaborn as sns

# %%
api_key = 'AIzaSyCu9pIvB6Tjq29f47PJqKaIVb_tfbJ9sm0'

channel_ids = ['UCwWhs_6x42TyRM4Wstoq8HA', #Dailyshow
               'UCtRa82x1BwQdnpHf0Es4gcQ', #Brooklyn Nine-Nine
               'UCVTyTA7-g9nopHeHbeuvpRA', #Late Night with Seth Meyers 
               'UCJ0uqCI0Vqr2Rrt1HseGirg', #The Late Late Show with James Corden
               'UCMtFAi84ehTSYSE9XoHefig' #The Late Show with Stephen Colbert 
              ]

youtube = build('youtube', 'v3', developerKey = api_key)

# %% [markdown]
# ## Function to get Channel Statistics

# %%
def get_channel_stats(youtube, channel_ids):
    all_data = []
    request = youtube.channels().list(
                        part = 'snippet, contentDetails, statistics',
                        id = ','.join(channel_ids)
                )
    response = request.execute()
    
    for i in range(len(response['items'])):
        data = dict(Channel_name = response['items'][i]['snippet']['title'],
                   Subscribers = response['items'][i]['statistics']['subscriberCount'],
                   Views = response['items'][i]['statistics']['viewCount'],
                   Total_videos = response['items'][i]['statistics']['videoCount'],
                   playlist_id = response['items'][i]['contentDetails']['relatedPlaylists']['uploads'])
       
        all_data.append(data)
        
    return all_data

# %%
statistics = get_channel_stats(youtube, channel_ids)

# %%
# with open('results.json', 'w') as outfile:
#     json.dump(statistics, outfile)

# %%
df = pd.DataFrame(statistics)
df
# Out:
#                            Channel_name Subscribers       Views Total_videos  \
# 0       The Daily Show with Trevor Noah     9880000  4622027487         4177
# 1           Late Night with Seth Meyers     4320000  2725543770         4241
# 2                    Brooklyn Nine-Nine      626000   759118775         1616
# 3  The Late Late Show with James Corden    27700000  9879742307         5357
# 4    The Late Show with Stephen Colbert     8870000  8539658012         9374
#
#                 playlist_id
# 0  UUwWhs_6x42TyRM4Wstoq8HA
# 1  UUVTyTA7-g9nopHeHbeuvpRA
# 2  UUtRa82x1BwQdnpHf0Es4gcQ
# 3  UUJ0uqCI0Vqr2Rrt1HseGirg
# 4  UUMtFAi84ehTSYSE9XoHefig

# %%
df['Subscribers'] = pd.to_numeric(df['Subscribers'])
df['Views'] = pd.to_numeric(df['Views'])
df['Total_videos'] = pd.to_numeric(df['Total_videos'])

df.dtypes
# Out:
# Channel_name    object
# Subscribers      int64
# Views            int64
# Total_videos     int64
# playlist_id     object
# dtype: object

# %%
sns.set(rc = {'figure.figsize': (10,8)})
ax = sns.barplot(x='Channel_name', y='Subscribers', data=df)

# %%
ax = sns.barplot(x='Channel_name', y='Views', data=df)

# %% [markdown]
# ## Function to get Video ID's

# %%
playlist_id = df.loc[df['Channel_name']=='The Late Late Show with James Corden', 'playlist_id'].iloc[0]

# %%
playlist_id
# Out:
# 'UUJ0uqCI0Vqr2Rrt1HseGirg'

# %%
df
# Out:
#                            Channel_name  Subscribers       Views  \
# 0       The Daily Show with Trevor Noah      9880000  4622027487
# 1           Late Night with Seth Meyers      4320000  2725543770
# 2                    Brooklyn Nine-Nine       626000   759118775
# 3  The Late Late Show with James Corden     27700000  9879742307
# 4    The Late Show with Stephen Colbert      8870000  8539658012
#
#    Total_videos               playlist_id
# 0          4177  UUwWhs_6x42TyRM4Wstoq8HA
# 1          4241  UUVTyTA7-g9nopHeHbeuvpRA
# 2          1616  UUtRa82x1BwQdnpHf0Es4gcQ
# 3          5357  UUJ0uqCI0Vqr2Rrt1HseGirg
# 4          9374  UUMtFAi84ehTSYSE9XoHefig

# %%
def get_video_ids(youtube, playlist_id):
    request = youtube.playlistItems().list(
                part='contentDetails',
                playlistId = playlist_id,
                maxResults = 50 # 50 is the max value I can pass, so I have to write a logic
    )
    response = request.execute()
        
    video_ids = []
    for i in range(len(response['items'])):
        video_ids.append(response['items'][i]['contentDetails']['videoId'])
    
    next_page_token = response.get('nextPageToken')
    more_pages = True
    while more_pages:
        if next_page_token is None:
            more_pages = False
        else:
            request = youtube.playlistItems().list(
                        part='contentDetails',
                        playlistId = playlist_id,
                        maxResults = 50,
                        pageToken = next_page_token)
            response = request.execute()
            for i in range(len(response['items'])):
                video_ids.append(response['items'][i]['contentDetails']['videoId'])
            next_page_token = response.get('nextPageToken')
    
    return video_ids

# %%
videos_ids = get_video_ids(youtube, playlist_id)
# videos_ids

# %% [markdown]
# ## Function to get Video Details

# %%
def get_video_details(youtube, videos_ids):
    all_video_stats = []
    for i in range(0, len(videos_ids), 50):
        request = youtube.videos().list(
                        part='snippet, statistics',
                        #it will start iterating from 0 to 50, then continue from 50 to 100 and so on. Since 50 is the max requests we can make at a time
                        id=','.join(videos_ids[i:i+50]))
        response = request.execute()
        
        for video in response['items']:
            video_stats = dict(Title = video['snippet']['title'],
                              Published_date = video['snippet']['publishedAt'],
                              Views = video['statistics']['viewCount'],
                              Likes = video['statistics']['likeCount']
                              )
            all_video_stats.append(video_stats)
    
    return all_video_stats

# %%
video_details = get_video_details(youtube, videos_ids)

video_data = pd.DataFrame(video_details)
video_data
# Out:
#                                                   Title        Published_date  \
# 0                            Benson Boone: In The Stars  2022-06-07T08:35:47Z
# 1                Juliette Lewis Never Believes the Hype  2022-06-07T08:35:38Z
# 2      LSD & Meryl Streep Led Viggo Mortensen to Acting  2022-06-07T08:35:28Z
# 3                                      Honest Headlines  2022-06-07T08:35:07Z
# 4               James Corden Recaps the Queen's Jubilee  2022-06-07T05:23:38Z
# ...                                                 ...                   ...
# 5352  The Late Late Show - Meet James Corden - Hidin...  2015-03-17T22:25:22Z
# 5353          The Late Late Show - Billboard Time Lapse  2015-03-16T19:11:30Z
# 5354  Late Late Show Soundcheck with James Corden an...  2015-03-10T14:00:03Z
# 5355  Late Late Show with James Corden - The Real On...  2015-02-09T03:48:04Z
# 5356   Late Late Show with James Corden YouTube Trailer  2015-02-07T22:30:01Z
#
#        Views  Likes
# 0       5809    598
# 1       5671    171
# 2       7274    411
# 3       4785    263
# 4      65118   1914
# ...      ...    ...
# 5352  109146   1171
# 5353   46185    785
# 5354   32480    881
# 5355  518161  10716
# 5356  193328   5168
#
# [5357 rows x 4 columns]

# %%
video_data['Published_date'] = pd.to_datetime(video_data['Published_date']).dt.date
video_data['Views'] = pd.to_numeric(video_data['Views'])
video_data['Likes'] = pd.to_numeric(video_data['Likes'])

# %%
# video_data.to_csv('Late_Show_James_Corden.csv')

# %%
video_data.dtypes
# Out:
# Title             object
# Published_date    object
# Views              int64
# Likes              int64
# dtype: object

# %% [markdown]
# ## Top 10 videos of ***`Late Late Show with James Corden`***

# %%
top10 = video_data.sort_values(by='Views', ascending=False)[:10]
top10
# Out:
#                                        Title Published_date      Views  \
# 4651                   Adele Carpool Karaoke     2016-01-14  254966681
# 4703           One Direction Carpool Karaoke     2015-12-16  190397611
# 5160           Justin Bieber Carpool Karaoke     2015-05-21  157649508
# 4562                     Sia Carpool Karaoke     2016-02-17  148091015
# 3931              Bruno Mars Carpool Karaoke     2016-12-14  145589246
# 4264            Selena Gomez Carpool Karaoke     2016-06-21  114760673
# 1505                     BTS Carpool Karaoke     2020-02-26   99003063
# 4456          Jennifer Lopez Carpool Karaoke     2016-03-30   93400325
# 4792  Justin Bieber Carpool Karaoke - Vol. 2     2015-11-19   92442603
# 3592              Ed Sheeran Carpool Karaoke     2017-06-07   87782431
#
#         Likes
# 4651  3264615
# 4703  3331898
# 5160  2102420
# 4562  2261133
# 3931  2338493
# 4264  2017512
# 1505  4418344
# 4456   961124
# 4792  1268266
# 3592  1678703

# %%
ax1 = sns.barplot(x='Views', y='Title', data=top10)

# %% [markdown]
# ## How many videos does ***`James Cordon`*** Posts each month on an average

# %%
video_data['Month'] = pd.to_datetime(video_data['Published_date']).dt.strftime('%b')

# %%
video_data.head()
# Out:
#                                               Title Published_date  Views  \
# 0                        Benson Boone: In The Stars     2022-06-07   5809
# 1            Juliette Lewis Never Believes the Hype     2022-06-07   5671
# 2  LSD & Meryl Streep Led Viggo Mortensen to Acting     2022-06-07   7274
# 3                                  Honest Headlines     2022-06-07   4785
# 4           James Corden Recaps the Queen's Jubilee     2022-06-07  65118
#
#    Likes Month
# 0    598   Jun
# 1    171   Jun
# 2    411   Jun
# 3    263   Jun
# 4   1914   Jun

# %%
monthly_videos = video_data.groupby('Month', as_index=False).size()
monthly_videos
# Out:
#    Month  size
# 0    Apr   519
# 1    Aug   359
# 2    Dec   381
# 3    Feb   451
# 4    Jan   404
# 5    Jul   192
# 6    Jun   417
# 7    Mar   575
# 8    May   571
# 9    Nov   508
# 10   Oct   466
# 11   Sep   514

# %%
sort_order = ['Jan','Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

monthly_videos.index = pd.CategoricalIndex(monthly_videos['Month'], categories=sort_order, ordered=True)
monthly_videos = monthly_videos.sort_index()

monthly_videos
# Out:
#       Month  size
# Month
# Jan     Jan   404
# Feb     Feb   451
# Mar     Mar   575
# Apr     Apr   519
# May     May   571
# Jun     Jun   417
# Jul     Jul   192
# Aug     Aug   359
# Sep     Sep   514
# Oct     Oct   466
# Nov     Nov   508
# Dec     Dec   381

# %%
ax2 = sns.barplot(x='Month', y='size', data=monthly_videos)

# %% [markdown]
# **Author: Jammal Adeyemi**
